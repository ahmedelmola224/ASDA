# %% [markdown]
# ## World Bank Project

# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Import libraries for running ANOVA and post-hoc test
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %% [markdown]
# #### Loading and Merging data

# %%
df1=pd.read_csv("world_bank_development_indicators.csv")
df2=pd.read_excel("income.xlsx")
df = pd.merge(df1, df2, left_on='country', right_on='Economy', how="inner")

# %% [markdown]
# #### Data Inspection

# %%
df.head()
# Out:
#        country        date  agricultural_land%  forest_land%  land_area  \
# 0  Afghanistan  1960-01-01                 NaN           NaN        NaN
# 1  Afghanistan  1961-01-01           57.878356           NaN   652230.0
# 2  Afghanistan  1962-01-01           57.955016           NaN   652230.0
# 3  Afghanistan  1963-01-01           58.031676           NaN   652230.0
# 4  Afghanistan  1964-01-01           58.116002           NaN   652230.0
#
#    avg_precipitation  trade_in_services%  control_of_corruption_estimate  \
# 0                NaN                 NaN                             NaN
# 1              327.0                 NaN                             NaN
# 2              327.0                 NaN                             NaN
# 3              327.0                 NaN                             NaN
# 4              327.0                 NaN                             NaN
#
#    control_of_corruption_std  access_to_electricity%  ...  population  \
# 0                        NaN                     NaN  ...   8622466.0
# 1                        NaN                     NaN  ...   8790140.0
# 2                        NaN                     NaN  ...   8969047.0
# 3                        NaN                     NaN  ...   9157465.0
# 4                        NaN                     NaN  ...   9355514.0
#
#    rural_population  voice_and_accountability_estimate  \
# 0         7898093.0                                NaN
# 1         8026804.0                                NaN
# 2         8163985.0                                NaN
# 3         8308019.0                                NaN
# 4         8458694.0                                NaN
#
#    voice_and_accountability_std  intentional_homicides      Economy  Code  \
# 0                           NaN                    NaN  Afghanistan   AFG
# 1                           NaN                    NaN  Afghanistan   AFG
# 2                           NaN                    NaN  Afghanistan   AFG
# 3                           NaN                    NaN  Afghanistan   AFG
# 4                           NaN                    NaN  Afghanistan   AFG
#
#                                               Region  Income group  \
# 0  Middle East, North Africa, Afghanistan & Pakistan    Low income
# 1  Middle East, North Africa, Afghanistan & Pakistan    Low income
# 2  Middle East, North Africa, Afghanistan & Pakistan    Low income
# 3  Middle East, North Africa, Afghanistan & Pakistan    Low income
# 4  Middle East, North Africa, Afghanistan & Pakistan    Low income
#
#    Lending category
# 0               IDA
# 1               IDA
# 2               IDA
# 3               IDA
# 4               IDA
#
# [5 rows x 55 columns]

# %%
df.sample(8)
# Out:
#               country        date  agricultural_land%  forest_land%  \
# 689         Argentina  2009-01-01           45.430209     11.155958
# 11243          Norway  1974-01-01            2.466844           NaN
# 14241        Suriname  1997-01-01            0.564103     98.409603
# 5768          Grenada  1970-01-01           64.705882           NaN
# 5818          Grenada  2020-01-01           23.529412     52.058824
# 13193        Slovenia  2004-01-01           24.428997     61.499503
# 4856   European Union  2018-01-01           40.967514     39.750997
# 1053     Bahamas, The  1989-01-01            1.098901           NaN
#
#          land_area  avg_precipitation  trade_in_services%  \
# 689    2736690.000              591.0            6.931803
# 11243   365244.000             1414.0                 NaN
# 14241   156000.000             2331.0                 NaN
# 5768       340.000             2350.0                 NaN
# 5818       340.000             2350.0           57.403937
# 13193    20140.000             1162.0           17.656365
# 4856   3996556.579                NaN           26.037636
# 1053     10010.000             1292.0           65.195950
#
#        control_of_corruption_estimate  control_of_corruption_std  \
# 689                         -0.445475                   0.153026
# 11243                             NaN                        NaN
# 14241                             NaN                        NaN
# 5768                              NaN                        NaN
# 5818                         0.357018                   0.204005
# 13193                        1.015796                   0.147816
# 4856                              NaN                        NaN
# 1053                              NaN                        NaN
#
#        access_to_electricity%  ...   population  rural_population  \
# 689                 97.792206  ...   40684338.0         3787305.0
# 11243                     NaN  ...    3985258.0         1287119.0
# 14241                     NaN  ...     452887.0          152972.0
# 5768                      NaN  ...      98794.0           66970.0
# 5818                93.355568  ...     123663.0           78480.0
# 13193              100.000000  ...    1997012.0          972385.0
# 4856                99.971837  ...  447001100.0       113909579.0
# 1053                      NaN  ...     265493.0           55000.0
#
#        voice_and_accountability_estimate  voice_and_accountability_std  \
# 689                             0.280091                      0.113063
# 11243                                NaN                           NaN
# 14241                                NaN                           NaN
# 5768                                 NaN                           NaN
# 5818                            0.687311                      0.205946
# 13193                           1.112389                      0.161861
# 4856                                 NaN                           NaN
# 1053                                 NaN                           NaN
#
#        intentional_homicides         Economy  Code                     Region  \
# 689                 6.493899       Argentina   ARG  Latin America & Caribbean
# 11243                    NaN          Norway   NOR      Europe & Central Asia
# 14241                    NaN        Suriname   SUR  Latin America & Caribbean
# 5768                     NaN         Grenada   GRD  Latin America & Caribbean
# 5818               11.321090         Grenada   GRD  Latin America & Caribbean
# 13193               1.352217        Slovenia   SVN      Europe & Central Asia
# 4856                     NaN  European Union   EUU                        NaN
# 1053                     NaN    Bahamas, The   BHS  Latin America & Caribbean
#
#               Income group  Lending category
# 689    Upper middle income              IBRD
# 11243          High income               NaN
# 14241  Upper middle income             Blend
# 5768   Upper middle income             Blend
# 5818   Upper middle income             Blend
# 13193          High income               NaN
# 4856                   NaN               NaN
# 1053           High income               NaN
#
# [8 rows x 55 columns]

# %%
# Information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16219 entries, 0 to 16218
# Data columns (total 55 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   country                                    16219 non-null  object
#  1   date                                       16219 non-null  object
#  2   agricultural_land%                         13921 non-null  float64
#  3   forest_land%                               7751 non-null   float64
#  4   land_area                                  14126 non-null  float64
#  5   avg_precipitation                          9726 non-null   float64
#  6   trade_in_services%                         8776 non-null   float64
#  7   control_of_corruption_estimate             4639 non-null   float64
#  8   control_of_corruption_std                  4639 non-null   float64
#  9   access_to_electricity%                     6989 non-null   float64
#  10  renewvable_energy_consumption%             7639 non-null   float64
#  11  electric_power_consumption                 7314 non-null   float64
#  12  CO2_emisions                               7036 non-null   float64
#  13  other_greenhouse_emisions                  7036 non-null   float64
#  14  population_density                         14097 non-null  float64
#  15  inflation_annual%                          10251 non-null  float64
#  16  real_interest_rate                         4341 non-null   float64
#  17  risk_premium_on_lending                    2350 non-null   float64
#  18  research_and_development_expenditure%      2772 non-null   float64
#  19  central_goverment_debt%                    2037 non-null   float64
#  20  tax_revenue%                               4993 non-null   float64
#  21  expense%                                   4658 non-null   float64
#  22  goverment_effectiveness_estimate           4615 non-null   float64
#  23  goverment_effectiveness_std                4615 non-null   float64
#  24  human_capital_index                        589 non-null    float64
#  25  doing_business                             183 non-null    float64
#  26  time_to_get_operation_license              356 non-null    float64
#  27  statistical_performance_indicators         1203 non-null   float64
#  28  individuals_using_internet%                7629 non-null   float64
#  29  logistic_performance_index                 1327 non-null   float64
#  30  military_expenditure%                      9550 non-null   float64
#  31  GDP_current_US                             12530 non-null  float64
#  32  political_stability_estimate               4676 non-null   float64
#  33  political_stability_std                    4676 non-null   float64
#  34  rule_of_law_estimate                       4729 non-null   float64
#  35  rule_of_law_std                            4729 non-null   float64
#  36  regulatory_quality_estimate                4617 non-null   float64
#  37  regulatory_quality_std                     4617 non-null   float64
#  38  government_expenditure_on_education%       5843 non-null   float64
#  39  government_health_expenditure%             4707 non-null   float64
#  40  multidimensional_poverty_headcount_ratio%  433 non-null    float64
#  41  gini_index                                 2075 non-null   float64
#  42  birth_rate                                 15169 non-null  float64
#  43  death_rate                                 15151 non-null  float64
#  44  life_expectancy_at_birth                   15003 non-null  float64
#  45  population                                 15783 non-null  float64
#  46  rural_population                           15657 non-null  float64
#  47  voice_and_accountability_estimate          4706 non-null   float64
#  48  voice_and_accountability_std               4706 non-null   float64
#  49  intentional_homicides                      4103 non-null   float64
#  50  Economy                                    16219 non-null  object
#  51  Code                                       16219 non-null  object
#  52  Region                                     13471 non-null  object
#  53  Income group                               13343 non-null  object
#  54  Lending category                           8991 non-null   object
# dtypes: float64(48), object(7)
# memory usage: 6.8+ MB

# %%
# Dataset Shape
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (16219, 55)

# %%
# columns in the dataset 
print("Columns in the dataset:")
for col in df.columns:
    print(col)
# Out:
# Columns in the dataset:
# country
# date
# agricultural_land%
# forest_land%
# land_area
# avg_precipitation
# trade_in_services%
# control_of_corruption_estimate
# control_of_corruption_std
# access_to_electricity%
# renewvable_energy_consumption%
# electric_power_consumption
# CO2_emisions
# other_greenhouse_emisions
# population_density
# inflation_annual%
# real_interest_rate
# risk_premium_on_lending
# research_and_development_expenditure%
# central_goverment_debt%
# tax_revenue%
# expense%
# goverment_effectiveness_estimate
# goverment_effectiveness_std
# human_capital_index
# doing_business
# time_to_get_operation_license
# statistical_performance_indicators
# individuals_using_internet%
# logistic_performance_index
# military_expenditure%
# GDP_current_US
# political_stability_estimate
# political_stability_std
# rule_of_law_estimate
# rule_of_law_std
# regulatory_quality_estimate
# regulatory_quality_std
# government_expenditure_on_education%
# government_health_expenditure%
# multidimensional_poverty_headcount_ratio%
# gini_index
# birth_rate
# death_rate
# life_expectancy_at_birth
# population
# rural_population
# voice_and_accountability_estimate
# voice_and_accountability_std
# intentional_homicides
# Economy
# Code
# Region
# Income group
# Lending category

# %%
# percentage of missing values in each column
missing_percentage = df.isnull().mean() * 100
print("Percentage of missing values in each column:")
print(missing_percentage)
# Out:
# Percentage of missing values in each column:
# country                                       0.000000
# date                                          0.000000
# agricultural_land%                           14.168568
# forest_land%                                 52.210371
# land_area                                    12.904618
# avg_precipitation                            40.033294
# trade_in_services%                           45.890622
# control_of_corruption_estimate               71.397743
# control_of_corruption_std                    71.397743
# access_to_electricity%                       56.908564
# renewvable_energy_consumption%               52.900919
# electric_power_consumption                   54.904741
# CO2_emisions                                 56.618780
# other_greenhouse_emisions                    56.618780
# population_density                           13.083421
# inflation_annual%                            36.796350
# real_interest_rate                           73.235095
# risk_premium_on_lending                      85.510821
# research_and_development_expenditure%        82.908934
# central_goverment_debt%                      87.440656
# tax_revenue%                                 69.215118
# expense%                                     71.280597
# goverment_effectiveness_estimate             71.545718
# goverment_effectiveness_std                  71.545718
# human_capital_index                          96.368457
# doing_business                               98.871694
# time_to_get_operation_license                97.805043
# statistical_performance_indicators           92.582773
# individuals_using_internet%                  52.962575
# logistic_performance_index                   91.818238
# military_expenditure%                        41.118441
# GDP_current_US                               22.744929
# political_stability_estimate                 71.169616
# political_stability_std                      71.169616
# rule_of_law_estimate                         70.842839
# rule_of_law_std                              70.842839
# regulatory_quality_estimate                  71.533387
# regulatory_quality_std                       71.533387
# government_expenditure_on_education%         63.974351
# government_health_expenditure%               70.978482
# multidimensional_poverty_headcount_ratio%    97.330292
# gini_index                                   87.206363
# birth_rate                                    6.473889
# death_rate                                    6.584870
# life_expectancy_at_birth                      7.497380
# population                                    2.688205
# rural_population                              3.465072
# voice_and_accountability_estimate            70.984648
# voice_and_accountability_std                 70.984648
# intentional_homicides                        74.702509
# Economy                                       0.000000
# Code                                          0.000000
# Region                                       16.943091
# Income group                                 17.732289
# Lending category                             44.565016
# dtype: float64

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# country                                          0
# date                                             0
# agricultural_land%                            2298
# forest_land%                                  8468
# land_area                                     2093
# avg_precipitation                             6493
# trade_in_services%                            7443
# control_of_corruption_estimate               11580
# control_of_corruption_std                    11580
# access_to_electricity%                        9230
# renewvable_energy_consumption%                8580
# electric_power_consumption                    8905
# CO2_emisions                                  9183
# other_greenhouse_emisions                     9183
# population_density                            2122
# inflation_annual%                             5968
# real_interest_rate                           11878
# risk_premium_on_lending                      13869
# research_and_development_expenditure%        13447
# central_goverment_debt%                      14182
# tax_revenue%                                 11226
# expense%                                     11561
# goverment_effectiveness_estimate             11604
# goverment_effectiveness_std                  11604
# human_capital_index                          15630
# doing_business                               16036
# time_to_get_operation_license                15863
# statistical_performance_indicators           15016
# individuals_using_internet%                   8590
# logistic_performance_index                   14892
# military_expenditure%                         6669
# GDP_current_US                                3689
# political_stability_estimate                 11543
# political_stability_std                      11543
# rule_of_law_estimate                         11490
# rule_of_law_std                              11490
# regulatory_quality_estimate                  11602
# regulatory_quality_std                       11602
# government_expenditure_on_education%         10376
# government_health_expenditure%               11512
# multidimensional_poverty_headcount_ratio%    15786
# gini_index                                   14144
# birth_rate                                    1050
# death_rate                                    1068
# life_expectancy_at_birth                      1216
# population                                     436
# rural_population                               562
# voice_and_accountability_estimate            11513
# voice_and_accountability_std                 11513
# intentional_homicides                        12116
# Economy                                          0
# Code                                             0
# Region                                        2748
# Income group                                  2876
# Lending category                              7228
# dtype: int64

# %%
# decribe the dataset
df.describe()
# Out:
#        agricultural_land%  forest_land%     land_area  avg_precipitation  \
# count        13921.000000   7751.000000  1.412600e+04        9726.000000
# mean            36.769780     32.727641  4.927244e+06        1201.597779
# std             20.806880     23.513946  1.429803e+07         801.490248
# min              0.262821      0.000000  2.027000e+00          18.100000
# 25%             19.797589     12.543726  2.072000e+04         589.000000
# 50%             37.470223     31.101989  1.998100e+05        1083.000000
# 75%             50.738916     47.498275  1.246700e+06        1738.000000
# max             93.440750     98.574551  1.299507e+08        3240.000000
#
#        trade_in_services%  control_of_corruption_estimate  \
# count         8776.000000                     4639.000000
# mean            21.381320                       -0.012059
# std             23.592171                        1.004910
# min              0.621025                       -1.936706
# 25%              8.764372                       -0.791940
# 50%             13.688930                       -0.243968
# 75%             25.388801                        0.695926
# max            327.166162                        2.459118
#
#        control_of_corruption_std  access_to_electricity%  \
# count                4639.000000             6989.000000
# mean                    0.203455               80.623744
# std                     0.087821               28.955287
# min                     0.114062                0.533899
# 25%                     0.148039               68.321813
# 50%                     0.172068               98.556229
# 75%                     0.226898              100.000000
# max                     0.942502              100.000000
#
#        renewvable_energy_consumption%  electric_power_consumption  ...  \
# count                     7639.000000                 7314.000000  ...
# mean                        31.097157                 2980.947331  ...
# std                         29.813651                 4195.312605  ...
# min                          0.000000                    5.548906  ...
# 25%                          5.305000                  380.483549  ...
# 50%                         21.117526                 1394.407738  ...
# 75%                         53.537515                 4027.279627  ...
# max                         98.340000                54799.174708  ...
#
#        multidimensional_poverty_headcount_ratio%   gini_index    birth_rate  \
# count                                 433.000000  2075.000000  15169.000000
# mean                                   26.855810    37.786795     28.035763
# std                                    10.706123     8.893234     12.883225
# min                                     2.370000    20.700000      5.000000
# 25%                                    18.500000    31.200000     16.222842
# 50%                                    24.800000    35.600000     26.900000
# 75%                                    32.600000    43.300000     39.576000
# max                                    74.200000    65.800000     58.121000
#
#          death_rate  life_expectancy_at_birth    population  rural_population  \
# count  15151.000000              15003.000000  1.578300e+04      1.565700e+04
# mean      10.488044                 64.347022  2.125386e+08      1.215267e+08
# std        5.381069                 11.157735  7.227470e+08      4.153242e+08
# min        0.795000                 11.995000  2.646000e+03      0.000000e+00
# 25%        7.000000                 56.994500  9.005955e+05      4.176150e+05
# 50%        9.201780                 66.883000  6.250510e+06      2.919496e+06
# 75%       12.400000                 72.633219  3.706793e+07      1.649997e+07
# max      103.534000                 85.497561  7.950947e+09      3.435260e+09
#
#        voice_and_accountability_estimate  voice_and_accountability_std  \
# count                        4706.000000                   4706.000000
# mean                           -0.004632                      0.167190
# std                             0.995756                      0.064463
# min                            -2.313395                      0.102437
# 25%                            -0.823601                      0.126576
# 50%                             0.032819                      0.142200
# 75%                             0.905235                      0.196929
# max                             1.800992                      0.578548
#
#        intentional_homicides
# count            4103.000000
# mean                7.964641
# std                12.079899
# min                 0.000000
# 25%                 1.323974
# 50%                 3.327091
# 75%                 9.208205
# max               138.773986
#
# [8 rows x 48 columns]

# %%
# describe the dataset object type
df.describe(include=['object'])
# Out:
#             country        date      Economy   Code                 Region  \
# count         16219       16219        16219  16219                  13471
# unique          256          64          256    256                      7
# top     Afghanistan  1992-01-01  Afghanistan    AFG  Europe & Central Asia
# freq             64         256           64     64                   3648
#
#        Income group Lending category
# count         13343             8991
# unique            4                3
# top     High income             IBRD
# freq           5376             4191

# %%
# unique and number of unique values in country and Income group column and years
print("Number of Unique countries:", df['country'].nunique())
print("Number of Unique Years:", df['date'].nunique())
print("Number of  Unique indicators:", df['Income group'].nunique())
print("Countries:", df['country'].unique())
print("Indicators:", df['Income group'].unique())
print("Years:", df['date'].unique())
# Out:
# Number of Unique countries: 256
# Number of Unique Years: 64
# Number of  Unique indicators: 4
# Countries: ['Afghanistan' 'Africa Eastern and Southern' 'Africa Western and Central'
#  'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Arab World' 'Argentina' 'Armenia' 'Aruba'
#  'Australia' 'Austria' 'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh'
#  'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan'
#  'Bolivia' 'Bosnia and Herzegovina' 'Botswana' 'Brazil'
#  'British Virgin Islands' 'Brunei Darussalam' 'Bulgaria' 'Burkina Faso'
#  'Burundi' 'Cabo Verde' 'Cambodia' 'Cameroon' 'Canada'
#  'Caribbean small states' 'Cayman Islands' 'Central African Republic'
#  'Central Europe and the Baltics' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  'Croatia' 'Cuba' 'Cyprus' 'Czechia' 'Denmark' 'Djibouti' 'Dominica'
#  'Dominican Republic' 'Early-demographic dividend' 'East Asia & Pacific'
#  'East Asia & Pacific (IDA & IBRD)'
#  'East Asia & Pacific (excluding high income)' 'Ecuador'
#  'Egypt, Arab Rep.' 'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia'
#  'Eswatini' 'Ethiopia' 'Euro area' 'Europe & Central Asia'
#  'Europe & Central Asia (IDA & IBRD)'
#  'Europe & Central Asia (excluding high income)' 'European Union'
#  'Faroe Islands' 'Fiji' 'Finland'
#  'Fragile and conflict affected situations' 'France' 'French Polynesia'
#  'Gabon' 'Gambia, The' 'Georgia' 'Germany' 'Ghana' 'Gibraltar' 'Greece'
#  'Greenland' 'Grenada' 'Guam' 'Guatemala' 'Guinea' 'Guinea-Bissau'
#  'Guyana' 'Haiti' 'Heavily indebted poor countries (HIPC)' 'High income'
#  'Honduras' 'Hong Kong SAR, China' 'Hungary' 'IBRD only'
#  'IDA & IBRD total' 'IDA blend' 'IDA only' 'IDA total' 'Iceland' 'India'
#  'Indonesia' 'Iran, Islamic Rep.' 'Iraq' 'Ireland' 'Isle of Man' 'Israel'
#  'Italy' 'Jamaica' 'Japan' 'Jordan' 'Kazakhstan' 'Kenya' 'Kiribati'
#  "Korea, Dem. People's Rep." 'Korea, Rep.' 'Kosovo' 'Kuwait'
#  'Kyrgyz Republic' 'Lao PDR' 'Late-demographic dividend'
#  'Latin America & Caribbean' 'Latin America & Caribbean (IDA & IBRD)'
#  'Latin America & Caribbean (excluding high income)' 'Latvia'
#  'Least developed countries: UN classification' 'Lebanon' 'Lesotho'
#  'Liberia' 'Libya' 'Liechtenstein' 'Lithuania' 'Low & middle income'
#  'Low income' 'Lower middle income' 'Luxembourg' 'Macao SAR, China'
#  'Madagascar' 'Malawi' 'Malaysia' 'Maldives' 'Mali' 'Malta'
#  'Marshall Islands' 'Mauritania' 'Mauritius' 'Mexico'
#  'Micronesia, Fed. Sts.' 'Middle income' 'Moldova' 'Monaco' 'Mongolia'
#  'Montenegro' 'Morocco' 'Mozambique' 'Myanmar' 'Namibia' 'Nauru' 'Nepal'
#  'Netherlands' 'New Caledonia' 'New Zealand' 'Nicaragua' 'Niger' 'Nigeria'
#  'North America' 'North Macedonia' 'Northern Mariana Islands' 'Norway'
#  'OECD members' 'Oman' 'Other small states' 'Pacific island small states'
#  'Pakistan' 'Palau' 'Panama' 'Papua New Guinea' 'Paraguay' 'Peru'
#  'Philippines' 'Poland' 'Portugal' 'Post-demographic dividend'
#  'Pre-demographic dividend' 'Qatar' 'Romania' 'Russian Federation'
#  'Rwanda' 'Samoa' 'San Marino' 'Saudi Arabia' 'Senegal' 'Serbia'
#  'Seychelles' 'Sierra Leone' 'Singapore' 'Sint Maarten (Dutch part)'
#  'Slovak Republic' 'Slovenia' 'Small states' 'Solomon Islands'
#  'South Africa' 'South Asia' 'South Asia (IDA & IBRD)' 'South Sudan'
#  'Spain' 'Sri Lanka' 'St. Kitts and Nevis' 'St. Lucia'
#  'St. Martin (French part)' 'St. Vincent and the Grenadines'
#  'Sub-Saharan Africa' 'Sub-Saharan Africa (IDA & IBRD)'
#  'Sub-Saharan Africa (excluding high income)' 'Sudan' 'Suriname' 'Sweden'
#  'Switzerland' 'Syrian Arab Republic' 'Tajikistan' 'Tanzania' 'Thailand'
#  'Timor-Leste' 'Togo' 'Tonga' 'Trinidad and Tobago' 'Tunisia'
#  'Turkmenistan' 'Turks and Caicos Islands' 'Tuvalu' 'Uganda' 'Ukraine'
#  'United Arab Emirates' 'United Kingdom' 'United States'
#  'Upper middle income' 'Uruguay' 'Uzbekistan' 'Vanuatu' 'Venezuela, RB'
#  'Vietnam' 'Virgin Islands (U.S.)' 'West Bank and Gaza' 'World'
#  'Yemen, Rep.' 'Zambia' 'Zimbabwe']
# Indicators: ['Low income' nan 'Upper middle income' 'High income'
#  'Lower middle income']
# Years: ['1960-01-01' '1961-01-01' '1962-01-01' '1963-01-01' '1964-01-01'
#  '1965-01-01' '1966-01-01' '1967-01-01' '1968-01-01' '1969-01-01'
#  '1970-01-01' '1971-01-01' '1972-01-01' '1973-01-01' '1974-01-01'
#  '1975-01-01' '1976-01-01' '1977-01-01' '1978-01-01' '1979-01-01'
#  '1980-01-01' '1981-01-01' '1982-01-01' '1983-01-01' '1984-01-01'
#  '1985-01-01' '1986-01-01' '1987-01-01' '1988-01-01' '1989-01-01'
#  '1990-01-01' '1991-01-01' '1992-01-01' '1993-01-01' '1994-01-01'
#  '1995-01-01' '1996-01-01' '1997-01-01' '1998-01-01' '1999-01-01'
#  '2000-01-01' '2001-01-01' '2002-01-01' '2003-01-01' '2004-01-01'
#  '2005-01-01' '2006-01-01' '2007-01-01' '2008-01-01' '2009-01-01'
#  '2010-01-01' '2011-01-01' '2012-01-01' '2013-01-01' '2014-01-01'
#  '2015-01-01' '2016-01-01' '2017-01-01' '2018-01-01' '2019-01-01'
#  '2020-01-01' '2021-01-01' '2022-01-01' '2023-01-01']

# %%
# duplicated rows in the dataset
df.duplicated().sum()
# There are no duplicated rows in the dataset
# Out:
# np.int64(0)

# %%
# number of entries for each income group
df['Income group'].value_counts()
# Out:
# Income group
# High income            5376
# Upper middle income    3392
# Lower middle income    3039
# Low income             1536
# Name: count, dtype: int64

# %% [markdown]
# #### Data Cleaning

# %%
def map_continent(region):
    if isinstance(region, str):
        if 'East Asia' in region or 'Pacific' in region or 'South Asia' in region \
           or 'Afghanistan & Pakistan' in region or 'Asia' in region:
            return 'Asia'
        elif 'Europe' in region:
            return 'Europe'
        elif 'Latin America' in region or 'Caribbean' in region or 'South America' in region:
            return 'South America'
        elif 'Africa' in region or 'Middle East' in region:
            return 'Africa'
        elif 'North America' in region:
            return 'North America'
    return 'Other'  # for NaN or unknown values

# Apply mapping
df['continent'] = df['Region'].apply(map_continent)

# %%
df['continent'].unique()
# Out:
# array(['Asia', 'Other', 'Africa', 'South America', 'North America'],
#       dtype=object)

# %%
# countries names in country column edited to remove leading and trailing spaces
df['country'] = df['country'].str.strip()

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Africa Eastern and Southern',
#        'Africa Western and Central', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Antigua and Barbuda',
#        'Arab World', 'Argentina', 'Armenia', 'Aruba', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda',
#        'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'British Virgin Islands', 'Brunei Darussalam',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia',
#        'Cameroon', 'Canada', 'Caribbean small states', 'Cayman Islands',
#        'Central African Republic', 'Central Europe and the Baltics',
#        'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Early-demographic dividend',
#        'East Asia & Pacific', 'East Asia & Pacific (IDA & IBRD)',
#        'East Asia & Pacific (excluding high income)', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Euro area',
#        'Europe & Central Asia', 'Europe & Central Asia (IDA & IBRD)',
#        'Europe & Central Asia (excluding high income)', 'European Union',
#        'Faroe Islands', 'Fiji', 'Finland',
#        'Fragile and conflict affected situations', 'France',
#        'French Polynesia', 'Gabon', 'Gambia, The', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'Honduras', 'Hong Kong SAR, China', 'Hungary', 'IBRD only',
#        'IDA & IBRD total', 'IDA blend', 'IDA only', 'IDA total',
#        'Iceland', 'India', 'Indonesia', 'Iran, Islamic Rep.', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Kosovo', 'Kuwait',
#        'Kyrgyz Republic', 'Lao PDR', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (IDA & IBRD)',
#        'Latin America & Caribbean (excluding high income)', 'Latvia',
#        'Least developed countries: UN classification', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Luxembourg', 'Macao SAR, China', 'Madagascar', 'Malawi',
#        'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands',
#        'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Fed. Sts.',
#        'Middle income', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro',
#        'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
#        'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua',
#        'Niger', 'Nigeria', 'North America', 'North Macedonia',
#        'Northern Mariana Islands', 'Norway', 'OECD members', 'Oman',
#        'Other small states', 'Pacific island small states', 'Pakistan',
#        'Palau', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Post-demographic dividend',
#        'Pre-demographic dividend', 'Qatar', 'Romania',
#        'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
#        'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone',
#        'Singapore', 'Sint Maarten (Dutch part)', 'Slovak Republic',
#        'Slovenia', 'Small states', 'Solomon Islands', 'South Africa',
#        'South Asia', 'South Asia (IDA & IBRD)', 'South Sudan', 'Spain',
#        'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia',
#        'St. Martin (French part)', 'St. Vincent and the Grenadines',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (IDA & IBRD)',
#        'Sub-Saharan Africa (excluding high income)', 'Sudan', 'Suriname',
#        'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Tajikistan',
#        'Tanzania', 'Thailand', 'Timor-Leste', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela, RB', 'Vietnam', 'Virgin Islands (U.S.)',
#        'West Bank and Gaza', 'World', 'Yemen, Rep.', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
# rename dictionary for standardizing country names
rename_dict = {
    'Swaziland': 'Eswatini',
    'Congo, Dem. Rep.': 'Democratic Republic of the Congo',
    'Congo, Rep.': 'Republic of the Congo',
    'Russian Federation': 'Russia',
    'Syrian Arab Republic': 'Syria',
    'Iran, Islamic Rep.': 'Iran',
    'Egypt, Arab Rep.': 'Egypt',
    'Bahamas, The': 'Bahamas',
    'Gambia, The': 'Gambia',
    'Venezuela, RB': 'Venezuela',
    "Korea, Dem. People's Rep.": 'North Korea',
    "Korea, Rep.": 'South Korea',
    "Hong Kong SAR, China": 'Hong Kong',
    "Sint Maarten (Dutch part)": 'Sint Maarten',
    "Virgin Islands (U.S.)": 'U.S. Virgin Islands'
}

# exclude keywords list for filtering out non-country entries
exclude_keywords = [
    'income', 'IDA', 'IBRD', 'small states', 'World', 'Euro area', 
    'OECD', 'demographic dividend', 'Arab World', 'Fragile', 'Post-', 
    'Pre-', 'Early-', 'Late-', 'Sub-Saharan Africa', 'East Asia & Pacific', 
    'Latin America & Caribbean', 'North America', 'Africa Eastern', 'Africa Western', 
    'Europe & Central Asia', 'Central Europe and the Baltics', 'European Union'
]

# non_countries list for direct exclusion
non_countries = [
    'European Union',
    'South Asia',
    'Heavily indebted poor countries (HIPC)',
    'Least developed countries: UN classification'
]

def clean_country(name):
    if not isinstance(name, str):
        return np.nan
    for word in exclude_keywords:
        if word.lower() in name.lower():
            return np.nan
    if name in non_countries:
        return np.nan
    return rename_dict.get(name, name)

df['country_clean'] = df['country'].apply(clean_country)

print(df['country_clean'].unique())
# Out:
# ['Afghanistan' nan 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei Darussalam' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde'
#  'Cambodia' 'Cameroon' 'Canada' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Democratic Republic of the Congo'
#  'Republic of the Congo' 'Costa Rica' 'Croatia' 'Cuba' 'Cyprus' 'Czechia'
#  'Denmark' 'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador' 'Egypt'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Polynesia'
#  'Gabon' 'Gambia' 'Georgia' 'Germany' 'Ghana' 'Gibraltar' 'Greece'
#  'Greenland' 'Grenada' 'Guam' 'Guatemala' 'Guinea' 'Guinea-Bissau'
#  'Guyana' 'Haiti' 'Honduras' 'Hong Kong' 'Hungary' 'Iceland' 'India'
#  'Indonesia' 'Iran' 'Iraq' 'Ireland' 'Isle of Man' 'Israel' 'Italy'
#  'Jamaica' 'Japan' 'Jordan' 'Kazakhstan' 'Kenya' 'Kiribati' 'North Korea'
#  'South Korea' 'Kosovo' 'Kuwait' 'Kyrgyz Republic' 'Lao PDR' 'Latvia'
#  'Lebanon' 'Lesotho' 'Liberia' 'Libya' 'Liechtenstein' 'Lithuania'
#  'Luxembourg' 'Macao SAR, China' 'Madagascar' 'Malawi' 'Malaysia'
#  'Maldives' 'Mali' 'Malta' 'Marshall Islands' 'Mauritania' 'Mauritius'
#  'Mexico' 'Micronesia, Fed. Sts.' 'Moldova' 'Monaco' 'Mongolia'
#  'Montenegro' 'Morocco' 'Mozambique' 'Myanmar' 'Namibia' 'Nauru' 'Nepal'
#  'Netherlands' 'New Caledonia' 'New Zealand' 'Nicaragua' 'Niger' 'Nigeria'
#  'North Macedonia' 'Northern Mariana Islands' 'Norway' 'Oman' 'Pakistan'
#  'Palau' 'Panama' 'Papua New Guinea' 'Paraguay' 'Peru' 'Philippines'
#  'Poland' 'Portugal' 'Qatar' 'Romania' 'Russia' 'Rwanda' 'Samoa'
#  'San Marino' 'Saudi Arabia' 'Senegal' 'Serbia' 'Seychelles'
#  'Sierra Leone' 'Singapore' 'Sint Maarten' 'Slovak Republic' 'Slovenia'
#  'Solomon Islands' 'South Africa' 'South Sudan' 'Spain' 'Sri Lanka'
#  'St. Kitts and Nevis' 'St. Lucia' 'St. Martin (French part)'
#  'St. Vincent and the Grenadines' 'Sudan' 'Suriname' 'Sweden'
#  'Switzerland' 'Syria' 'Tajikistan' 'Tanzania' 'Thailand' 'Timor-Leste'
#  'Togo' 'Tonga' 'Tunisia' 'Turkmenistan' 'Turks and Caicos Islands'
#  'Tuvalu' 'Uganda' 'Ukraine' 'United Arab Emirates' 'United Kingdom'
#  'United States' 'Uruguay' 'Uzbekistan' 'Vanuatu' 'Venezuela' 'Vietnam'
#  'U.S. Virgin Islands' 'West Bank and Gaza' 'Yemen, Rep.' 'Zambia'
#  'Zimbabwe']

# %%
# rename the cleaned country column to country and drop the old country column as well as region column
df['country'] = df['country_clean']
df = df.drop(columns=['country_clean'])
df = df.drop(columns=['Region'])
df.sample(7)
# Out:
#                   country        date  agricultural_land%  forest_land%  \
# 1799             Botswana  1967-01-01           45.878990           NaN
# 3772             Dominica  2020-01-01           33.333333     63.826667
# 7605               Jordan  2015-01-01           11.897950      1.098220
# 15690             Vanuatu  1974-01-01            9.844135           NaN
# 1061              Bahamas  1997-01-01            0.999001     50.935065
# 6409            Hong Kong  1971-01-01           11.764706           NaN
# 15951  West Bank and Gaza  2012-01-01           66.551944      1.665449
#
#        land_area  avg_precipitation  trade_in_services%  \
# 1799    566730.0              416.0                 NaN
# 3772       750.0             2083.0           38.784883
# 7605     88780.0              111.0           28.243097
# 15690    12190.0             2000.0                 NaN
# 1061     10010.0             1292.0           38.356947
# 6409      1020.0                NaN                 NaN
# 15951     6020.0              402.0           14.469814
#
#        control_of_corruption_estimate  control_of_corruption_std  \
# 1799                              NaN                        NaN
# 3772                         0.557267                   0.226407
# 7605                         0.244418                   0.135990
# 15690                             NaN                        NaN
# 1061                              NaN                        NaN
# 6409                              NaN                        NaN
# 15951                       -0.257588                   0.257313
#
#        access_to_electricity%  ...  population  rural_population  \
# 1799                      NaN  ...    578723.0          549069.0
# 3772                99.997215  ...     71995.0           20814.0
# 7605                99.892761  ...   9494246.0          925119.0
# 15690                     NaN  ...     98790.0           85774.0
# 1061               100.000000  ...    310171.0           57704.0
# 6409                      NaN  ...   4045300.0          483858.0
# 15951               99.800000  ...   3979998.0         1010163.0
#
#        voice_and_accountability_estimate  voice_and_accountability_std  \
# 1799                                 NaN                           NaN
# 3772                            0.873136                      0.210281
# 7605                           -0.769377                      0.129909
# 15690                                NaN                           NaN
# 1061                                 NaN                           NaN
# 6409                                 NaN                           NaN
# 15951                          -0.935010                      0.153488
#
#        intentional_homicides               Economy  Code         Income group  \
# 1799                     NaN              Botswana   BWA  Upper middle income
# 3772               20.834925              Dominica   DMA  Upper middle income
# 7605                1.590437                Jordan   JOR  Lower middle income
# 15690                    NaN               Vanuatu   VUT  Lower middle income
# 1061               14.830553          Bahamas, The   BHS          High income
# 6409                     NaN  Hong Kong SAR, China   HKG          High income
# 15951               0.693090    West Bank and Gaza   PSE  Lower middle income
#
#        Lending category      continent
# 1799               IBRD         Africa
# 3772              Blend  South America
# 7605               IBRD           Asia
# 15690               IDA           Asia
# 1061                NaN  South America
# 6409                NaN           Asia
# 15951               NaN           Asia
#
# [7 rows x 55 columns]

# %%
# Edit columns names 
df.columns = [col.strip().lower().replace(' ', '_') for col in df.columns]
#change % in column names to _percent
df.columns = [col.replace('%', '_percent') for col in df.columns]
df.columns
# Out:
# Index(['country', 'date', 'agricultural_land_percent', 'forest_land_percent',
#        'avg_precipitation', 'trade_in_services_percent',
#        'control_of_corruption_estimate', 'access_to_electricity_percent',
#        'renewvable_energy_consumption_percent', 'co2_emisions',
#        'inflation_annual_percent', 'real_interest_rate',
#        'risk_premium_on_lending',
#        'research_and_development_expenditure_percent',
#        'central_goverment_debt_percent', 'tax_revenue_percent',
#        'expense_percent', 'goverment_effectiveness_estimate',
#        'human_capital_index', 'doing_business',
#        'time_to_get_operation_license', 'statistical_performance_indicators',
#        'individuals_using_internet_percent', 'logistic_performance_index',
#        'military_expenditure_percent', 'gdp_current_us',
#        'political_stability_estimate', 'rule_of_law_estimate',
#        'regulatory_quality_estimate',
#        'government_expenditure_on_education_percent',
#        'government_health_expenditure_percent',
#        'multidimensional_poverty_headcount_ratio_percent', 'gini_index',
#        'life_expectancy_at_birth', 'population',
#        'voice_and_accountability_estimate', 'intentional_homicides',
#        'income_group', 'continent'],
#       dtype='object')

# %%
# drop unnecessary columns for ANOVA test
# irrelevant columns and standard deviation columns
columns_to_drop = ['economy','code','lending_category']
std_cols = [c for c in df.columns if c.endswith('_std')]
# land_area, population_density, rural_population are irrelevant
# electric_power_consumption and other_greenhouse_emisions is raw emmisions and we have co2 emissions per capita
# birth_rate and death_rate are strongly correlated with life_expectancy
candidate_drop = [
    'rural_population','land_area','population_density',
    'birth_rate','death_rate',
    'electric_power_consumption','other_greenhouse_emisions'
]
df = df.drop(columns=columns_to_drop + std_cols + candidate_drop)

# %%
df.sample(5)
# Out:
#                                 country        date  agricultural_land%  \
# 13371                      South Africa  1990-01-01           78.807013
# 7263                        Isle of Man  1993-01-01           71.578947
# 2343                           Cambodia  1999-01-01           26.285973
# 3166   Democratic Republic of the Congo  1990-01-01           11.451005
# 4380                            Eritrea  2021-01-01           62.722637
#
#        forest_land%  avg_precipitation  trade_in_services%  \
# 13371     14.955271              495.0            5.757060
# 7263       6.070175                NaN                 NaN
# 2343      61.202011             1904.0           16.649675
# 3166      66.442734             1543.0                 NaN
# 4380       8.692108                NaN                 NaN
#
#        control_of_corruption_estimate  access_to_electricity%  \
# 13371                             NaN                     NaN
# 7263                              NaN              100.000000
# 2343                              NaN                8.820037
# 3166                              NaN                     NaN
# 4380                        -1.257142               52.514050
#
#        renewvable_energy_consumption%  co2_emisions  ...  \
# 13371                           16.63      247614.7  ...
# 7263                             0.00           NaN  ...
# 2343                            81.53        1907.1  ...
# 3166                            92.05        3179.0  ...
# 4380                              NaN           NaN  ...
#
#        government_expenditure_on_education%  government_health_expenditure%  \
# 13371                               4.69768                             NaN
# 7263                                    NaN                             NaN
# 2343                                    NaN                             NaN
# 3166                                    NaN                             NaN
# 4380                                    NaN                             NaN
#
#        multidimensional_poverty_headcount_ratio%  gini_index  \
# 13371                                        NaN         NaN
# 7263                                         NaN         NaN
# 2343                                         NaN         NaN
# 3166                                         NaN         NaN
# 4380                                         NaN         NaN
#
#        life_expectancy_at_birth  population  \
# 13371                    63.375  39877570.0
# 7263                     72.310     70710.0
# 2343                     57.690  11899006.0
# 3166                     48.601  35987541.0
# 4380                     66.536   3620312.0
#
#        voice_and_accountability_estimate  intentional_homicides  \
# 13371                                NaN                    NaN
# 7263                                 NaN                    NaN
# 2343                                 NaN               4.882761
# 3166                                 NaN                    NaN
# 4380                            -1.93016                    NaN
#
#               income_group  continent
# 13371  Upper middle income     Africa
# 7263           High income       Asia
# 2343   Lower middle income       Asia
# 3166            Low income     Africa
# 4380            Low income     Africa
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['country', 'date', 'agricultural_land%', 'forest_land%',
#        'avg_precipitation', 'trade_in_services%',
#        'control_of_corruption_estimate', 'access_to_electricity%',
#        'renewvable_energy_consumption%', 'co2_emisions', 'inflation_annual%',
#        'real_interest_rate', 'risk_premium_on_lending',
#        'research_and_development_expenditure%', 'central_goverment_debt%',
#        'tax_revenue%', 'expense%', 'goverment_effectiveness_estimate',
#        'human_capital_index', 'doing_business',
#        'time_to_get_operation_license', 'statistical_performance_indicators',
#        'individuals_using_internet%', 'logistic_performance_index',
#        'military_expenditure%', 'gdp_current_us',
#        'political_stability_estimate', 'rule_of_law_estimate',
#        'regulatory_quality_estimate', 'government_expenditure_on_education%',
#        'government_health_expenditure%',
#        'multidimensional_poverty_headcount_ratio%', 'gini_index',
#        'life_expectancy_at_birth', 'population',
#        'voice_and_accountability_estimate', 'intentional_homicides',
#        'income_group', 'continent'],
#       dtype='object')

# %%
df[['gdp_per_capita','co2_per_capita']] = df[['gdp_current_us','co2_emisions']].div(df['population'].replace(0, np.nan), axis=0)
# drop the raw  columns
df = df.drop(columns=['gdp_current_us','co2_emisions'])
df.head()
# Out:
#        country       date  agricultural_land_percent  forest_land_percent  \
# 0  Afghanistan 1960-01-01                        NaN                  NaN
# 1  Afghanistan 1961-01-01                  57.878356                  NaN
# 2  Afghanistan 1962-01-01                  57.955016                  NaN
# 3  Afghanistan 1963-01-01                  58.031676                  NaN
# 4  Afghanistan 1964-01-01                  58.116002                  NaN
#
#    avg_precipitation  trade_in_services_percent  \
# 0                NaN                        NaN
# 1              327.0                        NaN
# 2              327.0                        NaN
# 3              327.0                        NaN
# 4              327.0                        NaN
#
#    control_of_corruption_estimate  access_to_electricity_percent  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    renewvable_energy_consumption_percent  inflation_annual_percent  ...  \
# 0                                    NaN                       NaN  ...
# 1                                    NaN                       NaN  ...
# 2                                    NaN                       NaN  ...
# 3                                    NaN                       NaN  ...
# 4                                    NaN                       NaN  ...
#
#    multidimensional_poverty_headcount_ratio_percent  gini_index  \
# 0                                               NaN         NaN
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                               NaN         NaN
# 4                                               NaN         NaN
#
#    life_expectancy_at_birth  population  voice_and_accountability_estimate  \
# 0                    32.535   8622466.0                                NaN
# 1                    33.068   8790140.0                                NaN
# 2                    33.547   8969047.0                                NaN
# 3                    34.016   9157465.0                                NaN
# 4                    34.494   9355514.0                                NaN
#
#    intentional_homicides  income_group  continent  gdp_per_capita  \
# 0                    NaN    Low income       Asia       62.369375
# 1                    NaN    Low income       Asia       62.443703
# 2                    NaN    Low income       Asia       60.950364
# 3                    NaN    Low income       Asia       82.021738
# 4                    NaN    Low income       Asia       85.511073
#
#    co2_per_capita
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 39 columns]

# %%
# check which years is suitable for Anova
df.groupby('date')[['gdp_per_capita','co2_per_capita']].apply(lambda x: x.isna().sum()).sort_values(by='gdp_per_capita').head(15)
# Out:
#             gdp_per_capita  co2_per_capita
# date
# 2011-01-01               9              29
# 2021-01-01              10             251
# 2014-01-01              10              29
# 2013-01-01              11              29
# 2012-01-01              11              29
# 2010-01-01              11              29
# 2019-01-01              12              29
# 2018-01-01              12              29
# 2017-01-01              12              29
# 2016-01-01              12              29
# 2015-01-01              12              29
# 2009-01-01              12              29
# 2008-01-01              12              29
# 2006-01-01              13              29
# 2020-01-01              13              29
